# %% [markdown]
# ## Install and import Dependencies

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
# !pip install transformers requests beautifulsoups pandas numpy

# %%
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# # Instantiate Model

# %%
tokenizer = AutoTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')
model = AutoModelForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')
# Out:
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/669M [00:00<?, ?B/s]

# %% [markdown]
# ## Encode and Calculate Sentiment

# %%
tokens = tokenizer.encode('I is Amazing,  I absolutely love this', return_tensors='pt')
tokens
# Out:
# tensor([[  101,   151, 10127, 39854,   117,   151, 35925, 10563, 11157, 10372,
#            102]])

# %%
tokenizer.decode(tokens[0])
# Out:
# '[CLS] i is amazing, i absolutely love this [SEP]'

# %%
result = model(tokens)
result
# Out:
# SequenceClassifierOutput(loss=None, logits=tensor([[-2.0720, -2.6410, -1.3616,  0.9258,  4.2240]],
#        grad_fn=<AddmmBackward0>), hidden_states=None, attentions=None)

# %%
torch.argmax(result.logits)
# Out:
# tensor(4)

# %%
result.logits
# Out:
# tensor([[-2.0720, -2.6410, -1.3616,  0.9258,  4.2240]],
#        grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Collect Reviews

# %%
r = requests.get('https://www.yelp.com/biz/mejico-sydney-2')
soup = BeautifulSoup(r.text,'html.parser')
regex = re.compile('.*comment.*')
results = soup.find_all('p',{'class':regex})
reviews = [result.text for result in results]

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/dcfe403147fc/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>\n            window.yelp = window.yelp || {};\n            window.yelp.cookieTypePreferencesHeader = \'["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]\';\n            window.OneTrust = window.OneTrust || {};\n            window.OneTrust.dataSubjectParams = window.OneTrust.dataSubjectParams || {};\n            window.OneTrust.dataSubjectParams.id = \'\';\n            window.OneTrust.dataSubjectParams.isAnonymous = true;\n\n            function addCookieManagementScript() {\n                var tag = document.createElement(\'script\');\n                tag.async = true;\n                tag.src = \'https://cdn.cookielaw.org/consent/5fbcd417-fbc1-4fcc-abad-f622f1bba72d/otSDKStub.js\';\n                tag.type = \'text/javascript\';\n                tag.charset = \'UTF-8\';\n                tag.setAttribute(\'data-domain-script\', \'5fbcd417-fbc1-4fcc-abad-f622f1bba72d\');\n                tag.setAttribute(\'data-document-language\', \'true\');\n\n                document.head.appendChild(tag);\n            }\n\n            if (\'requestIdleCallback\' in window) {\n                requestIdleCallback(addCookieManagementScript, { timeout: 4000 });\n            } else {\n                setTimeout(addCookieManagementScript, 2000);\n            }\n        </script><script async src="https://www.google-analytics.com/analytics.js"></script><script async src="https://www.googletagmanager.com/gtag/js?id=G-K9Z2ZEVC8C&l=ga4DataLayer"></script><script>window.ga4DataLayer=window.ga4DataLayer||[];function ga4Tag(){ga4DataLayer.push(arguments);};ga4Tag("js",new Date());ga4Tag("config","G-K9Z2ZEVC8C",{send_page_view:false});</script><meta id="emotion-container"><style data-id="server-emotion" data-emotion-css="xl0fej 1se75m6 1qn0b6x 1kfj3o 2wl9y 1i9k7ig 1feovq5 1wrui0y afumm9 s97lou kmgt1v 1xykegj ufd2i 174a15u 1s600d4 u9z0t tq6h5w 9ul5p9 2entjo sp00yl wvq5ds 99hrhj 1rjq8gp 16agjqd rfz18w 2ddiov f4x8dl spv88u eqfjza xlzvdl 13niwh7 1gquror 12anxc3 ux5mu6 chan6m 2i524w 4zp531 akjnuk 1h0y4i5 1u2qp1u 1p1tqzd xb3nz6 dh50jt i4guvk 1nrzw89 1ek4wor 1orhttt 1p745yy 1saxw1t 9is8m na7xnn 1jxkguo xzej2x 1d8srnw 182o411 4nweu3 ralh0w ccsinh nc88ol cq5uiq 1ip9g62 7fwgsn jg86o8 1xhnwcl 1i3gg8i 19uiqw4 cwr0q8 qgunke 1jq1ouh 1uzx7cn 1c9o6ng 12i50in kdumup rtu4wi 1qc4gmz 1t2vj63 1wlno2c gi3rm 13r89hs 17ed4v1 7xcklk 1y1s7b9 p8xp6y jmku3q 1mt9i4y 14nq5pj 1ci60an 1enow5j 1kq79li 12g1kk mbp3hu 1yu6q44 vtfyr5 1o3v5v5 v3nuob 1w4iqij 147xtl9 1wl4hh5 4tjnih gutk1c 6a0jil 1934n28 r3lhny l6gfjs x61rbl 17ut15w 9jorwr ded1ix 1wzthaf hnttcw 1v6kfrx 13pidrm 1dq6s1n 1fdy0l5 1x9ee72 19v1rkv 1luukq 1l4vfvy 1gojbyd 14r9eb 1xfc281 1fyi5wc tuynn7 1d810fm kzapgm wd82ue 1edlukf inq9gi xitv9p 1wpxijb 18ji5fs 10e8cfo cq0u28 tza3mu 4v7jbl 1h138a3 1hqozct 1hqkluu 2sacua 1sb02f4 1n40tdh 15j7fnr war30n 1p9ibgf 106vfgv 1inzsq1 1rocox3 r9996t 1idmmu3 n604h6 29kerx 1hgawz4 1iog7m3 xxqqxs qyp8bo 1wayfxy vaercj em5n90 1ltundv z8bp47 1u1p5a2 1596k8f nus9cm vndwiw 1evauet 14hbkfk 1d43y4s ije6j5 1q2nwpv nefexz 1pz4y59 1dys0n1 volmcs 1fncc ...

# %%
soup
# Out:
# <!DOCTYPE html>
# /,"js");</script><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en-US" http-equiv="Content-Language"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><link content="#FF1A1A" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" rel="mask-icon" sizes="any"/><link href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/dcfe403147fc/assets/img/logos/favicon.ico" rel="shortcut icon"/><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>
#             window.yelp = window.yelp || {};
#             window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#             window.OneTrust = window.OneTrust || {};
#             window.OneTrust.dataSubjectParams = window.OneTrust.dataSubjectParams || {
t16 14o0nng 1adhs7a 1e7audd 5d1n8n 1cfy6na 1ek5ind s45ty1 1cl0sai 1v73oz8 3u4ty s6uy2w 1kvnlux zvy9eo 1l5mloc 1w7tg8b 15gywx9 1hhdswe n9mvfp mxtc5f 5hgtfb 1lx34my ahgoya 1aq64zd 1mhgj6v 1p80smk s81j3n djo2w hmsl4n aeksxl sg3jc1 1t7f977 hp0sjs 1yxib76 1kk39bm 1knnyis 1jlm262 opmknv 1c994ch 1dvzjst 1pkb2vf 111aeby 1ixb7x1 1acpnfq 12rljwp 1o99tvw 1rsppcm zmbz7k sivbnu wsj3uf iw8c3l" data-id="server-emotion">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:600px){.responsive:not(.responsive-biz) .responsive-small-display-inline-block{display:inline-block !important;}.responsive:not(.responsive-biz) .responsive-small-display-block{display:block !important;}.responsive:not(.responsive-biz) .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-displ ...
# <script>
#         window.yelp = window.yelp || {};
#         window.yelp.critical_css = window.yelp.critical_css || {};
#         window.yelp.critical_css.css_map = {};
#     </script>
# <!-- css-middleware: bootstrap placeholder --><script>(function() { window.yelp.critical_css.recordDone=function(c,l){l.onload=null;var i=window.yelp.critical_css.css_map[c];window.yelp.critical_css.css_map[c]=i&&Object.keys(i).length?i:{loaded:!1,linkTag:l}}; })()</script>
# <meta name="critical_css_middleware"/><link data-rh="true" href="https://m.yelp.com/biz/mejico-sydney-2" media="only screen and (max-width: 640px)" rel="alternate"/><link data-rh="true" href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/><link data-rh="true" href="https://www.yelp.com/biz/mejico-sydney-2" rel="canonical"/><link data-rh="true" href="https://www.yelp.ca/biz/mejico-sydney-2" hreflang="en-ca" rel="alternate"/><link data-rh="true" href="https://www.yelp.com/biz/mejico-sydney-2" hreflang="en-us" rel="alternate"/><link data-rh="true" href="android-app://com.yelp.android/yelp-app-indexing/biz/n6POlWRs0X9c6caknED8hA?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/><link data-rh="true" href="ios-app://284910350/yelp//biz/n6POlWRs0X9c6caknED8hA?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google" rel="alternate"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-regular.yji-aff9b80e384301f2ae0c.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-semibold.yji-d3abae27d3eac73b40a5.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/open-sans-bold.yji-1145ff0b749fff2d31bb.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/poppins-bold.yji-9690ce6275ddc5645cfa.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-rh="true" href="https://s3-media0.fl.yelpcdn.com/assets/public/poppins-medium.yji-dc16a3592fdb61b620cc.woff2" rel="preload" type="font/woff2"/><link as="style" data-chunk="components-SEOLinks" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-SEOLinks.yji-1259881f05ec32d2c44b.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-RelatedBusinessesCarousel" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-ad59b36f17920d25a77f.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-CollectionCardCarousel" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-e7d10ddfaac6bd70be5b.chunk.css" rel="preload"/>
# <link as="style" data-chunk="Reviews" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/Reviews.yji-d5f7041ee252b863710d.chunk.css" rel="preload"/>
# <link as="style" data-chunk="Reviews" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-352143ac1589633d1e54fad16c786b800be79104-pkg.yji-5e0595fdd73c39220aa9.css" rel="preload"/>
# <link as="style" data-chunk="components-BizQuestionsGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-f99580137c641aaab850.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-MoreBusinessInfo" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-2b847120a4c94e3ba1f2.chunk.css" rel="preload"/>
# <link as="style" data-chunk="BizHoursGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-83eda371beaa69e36837.chunk.css" rel="preload"/>
# <link as="style" data-chunk="MapBoxV2GQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-4881c82d23ae7af43e76.chunk.css" rel="preload"/>
# <link as="style" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-f1b4734310b4ae199e76.chunk.css" rel="preload"/>
# <link as="style" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-ae3b196940cf34e1aebc.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-BusinessPostsGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BusinessPostsGQL.yji-361a751420ca4b884190.chunk.css" rel="preload"/>
# <link as="style" data-chunk="components-BizPageConfigurableAlertsGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-b7ac0249144a2954921c.chunk.css" rel="preload"/>
# <link as="style" data-chunk="ClaimStatusGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-f278275cd0028fbe6fd6.chunk.css" rel="preload"/>
# <link as="script" data-chunk="ClaimStatusGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-964f91986fe1f701f654.chunk.js" rel="preload"/>
# <link as="script" data-chunk="ClaimReminderGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimReminderGQL.yji-25267290e33dcb9e2de7.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-UnconfirmedReviewAlert" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-UnconfirmedReviewAlert.yji-af01e4e9b3e148d54e5b.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-BizPageConfigurableAlertsGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-22646887c4fdc1acab49.chunk.js" rel="preload"/>
# <link as="script" data-chunk="components-BusinessPostsGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BusinessPostsGQL.yji-7c9b3e012d3a8b1366c0.chunk.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-c618614aca1458d5bde2c6e5c567d2e268b6d9b2.yji-1eeae3ac4ad4a880ec95.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-80cc6ba903bd8dc0db2ea47b066e464f4b0e3ad7.yji-27b2217c00e3e7ad4c41.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-4385ce806a9aa42b8b757d0e0141a02132ddf8e2.yji-b389a61294e63009388f.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-a55b3590195b5b65959d6e783f1c7d019ef6538c.yji-2758c2b8dc232ec61a6e.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-97b496f4a6e24001c8f4.chunk.js" rel="preload"/>
# <link as="script" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" href="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji
function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script><title data-rh="true">MEJICO - Updated April 2024 - 181 Photos &amp; 87 Reviews - 105 Pitt St, Sydney New South Wales, Australia - Mexican - Restaurant Reviews - Phone Number - Yelp</title><meta content="87 reviews and 181 photos of Mejico &quot;So happy that a hip Mexican restaurant has opened in CBD.  I would describe the food as Latino flavors or fusion, as I have never seen a ocean trout taco or plantain chips served with salsa/guacamole in Mexico or southern California.  I wanted to like this new, hipster Mexican more.... Here's my take.
#
# PROS:
#  - Extensive tequila collection and they actually know how to make a margarita.
#  - Tableside guacamole is delicious.
#  - Nice selection of sides and ceviches.
#  - Decor, communal table, big bar and open kitchen make a great atmosphere.
#  - Good location for afterwork or evening play time, with super close proximity to Wynyard station.
#
# CONS:
#  - No regular, homemade tortilla chips.
#  - Not a traditional Mexican menu.  They serve ceviche, micro sized tacos of pork belly or ocean trout, a very strange take on queso (they executed Mexican haloumi), etc
#  - Margaritas had the right flavor and are served in a fun margarita glass, but they wanted to rim them in sugar (we said &quot;No. Salt please&quot;) and they are shaken over ice and then strained, rather than served on the rocks.
#  - Cafeteria style chairs and tables were a bit low end.
#
# I will be back, but I sure do wish they hit the traditional Mexican favorites like mole, enchiladas with crab and or salsa verde, real tortilla chips, a fabulous roasted or grilled chicken dish, proper carne asada (grilled steak), even beans &amp; rice.  You don't need to do Mexican street food to offer real, quality, high end Mexican food.&quot;" data-rh="true" name="description"/><meta content="n6POlWRs0X9c6caknED8hA" data-rh="true" name="yelp-biz-id"/><meta content="noarchive" data-rh="true" name="bingbot"/><meta content="Yelp" data-rh="true" property="og:site_name"/><meta content="yelpyelp:business" data-rh="true" property="og:type"/><meta content="https://s3-media0.fl.yelpcdn.com/bphoto/kEVvHLtBlb2dsQ60waOXiw/o.jpg" data-rh="true" property="og:image"/><meta content="3648" data-rh="true" property="og:image:height"/><meta content="5472" data-rh="true" property="og:image:width"/><meta content="Mejico - Sydney, NSW" data-rh="true" property="og:title"/><meta content="https://www.yelp.com/biz/mejico-sydney-2" data-rh="true" property="og:url"/><meta content="" data-rh="true" property="og:description"/><meta content="97534753161" data-rh="true" property="fb:app_id"/><meta content="app-id=284910350, app-argument=yelp:///biz/n6POlWRs0X9c6caknED8hA?utm_campaign=default&amp;amp;utm_source=www" data-rh="true" name="apple-itunes-app"/><meta content="Yelp" data-rh="true" property="al:ios:app_name"/><meta content="284910350" data-rh="true" property="al:ios:app_store_id"/><meta content="https://www.yelp.com/biz/mejico-sydney-2?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=apple" data-rh="true" property="al:ios:url"/><meta content="Yelp" data-rh="true" name="application-name"/><meta content="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/f5e05563b53a/ico/win8-tile.png" data-rh="true" name="msapplication-TileImage"/><meta content="\#FFFFFF" data-rh="true" name="msapplication-TileColor"/><meta content="https://www.yelp.com" data-rh="true" name="msapplication-starturl"/><meta content="\#FF1A1A" data-rh="true" name="msapplication-navbutton-color"/><meta content="width=1024;height=768" data-rh="true" name="msapplication-window"/><meta content="Go to https://www.yelp.com" data-rh="true" name="msapplication-tooltip"/><meta content="[object Object]" data-rh="true" name="msapplication-task"/><meta content="[object Object]" data-rh="true" name="msapplication-task"/><meta content="[object Object]" data-rh="true" name="msapplication-task"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-lib-yelp-react-component-arrange-14.0.3-pkg.yji-13b4903814928f1bd1e9.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-45678198df633c45c8340903d85eacef1d7287fc-pkg.yji-977b0114283dc486d137.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-6166e547bc9311b3375dc21698903ba0860381ce-pkg.yji-1fd08c8e82025dfd4cd0.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-1ce3f9f474ffbb95236437a4da47b077a9aa64a0-pkg.yji-a064b6de82466ae54da6.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-352143ac1589633d1e54fad16c786b800be79104-pkg.yji-5e0595fdd73c39220aa9.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-shared-151f206a7613c72c1f5154b8ac947f0044079ebe-pkg.yji-1c6ae6e35137625cdbc1.css" rel="stylesheet"/>
# <link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-gondola-biz-details-pkg.yji-dac1ab6f04e0c4861fb3.css" rel="stylesheet"/>
# <script>document.cookie = "xcj=1|musM700pB6VPUSxoyzEJt-6QcNtG_yNXt-2hR_sVJCA; Domain=.yelp.com; expires=Tue, 16 Jul 2024 06:46:19 GMT; Max-Age=7776000; Path=/";</script><link href="/opensearch" rel="search" title="Yelp" type="application/opensearchdescription+xml"/></head><body class="" style="margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline; line-height: 1;"><noscript></noscript><yelp-react-root><div data-hypernova-id="bdd1322d-8d7a-48dd-b5ab-07c8bf2f197a" data-hypernova-key="yelpfrontend__15489__yelpfrontend__GondolaBizDetails__dynamic"><div class="css-1qn0b6x"><ul class="css-1kfj3o"></ul></div><span class=""><!-- <a href="/biz/outlook-autumn-market-fundamental-catwalk-flimsy-roost-legibility-individualism-grocer-predestination-8">yelp</a> --></span><div class="alert-notice__09f24__WKrTt css-1qn0b6x" data-module-name="LegalBanner"><iframe class="cookie-iframe-banner__09f24__GnESl" frameborder="0" scrolling="no" src="/eu_cookie_notice?responsive" style="height:0px" tabindex="-1" title="cookie notice"></iframe></div><div class="v2__09f24__GsUJ_ css-kdumup" data-lcp-target-id="CONSUMER_HEADER"><div class="css-rtu4wi"><div class="a11y-menu-container__09f24__V3Frf css-1qn0b6x"></div></div><header class="consumer-header-container__09f24__ieW2P css-1qc4gmz"><div class="consumer-header__09f24__GAvyT css-1qn0b6x"><div class="arrange__09f24__LDfbs vertical-align-middle__09f24__zU9sE css-1qn0b6x"><div class="logo-arrange-unit__09f24__Rbwi3 arrange-unit__09f24__rqHTg css-1qn0b6x"><div class="css-1t2vj63"><div class="logo__09f24__ip022 logo-image__09f24__SXMH_ logo-container__09f24__jaSQB css-1qn0b6x" data-analytics-label="logo" id="logo" style="background-image:url(https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_design_cdn/7ef71bf77a33/assets/img/brand/logo_desktop.svg)"><a class="logo-link__09f24__fS20h css-f4x8dl" href="/">Yelp</a></div></div></div><div class="search-suggest-arrange-unit__09f24__zqa_F arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG css-1qn0b6x"><div class="search-suggest-container-outer__09f24__SUL4j css-1qn0b6x"><div class="search-suggest-container-inner__09f24__WsMGR css-1qn0b6x"><div class="arrange__09f24__LDfbs gutter-2__09f24__CCmUo css-1qn0b6x"><div class="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG css-1qn0b6x"><form action="/search" class="css-1wlno2c ewsdu8x4" data-testid="searchSuggest" id="header_find_form" method="get" role="search"><div class="ewsdu8x0 css-gi3rm"><label class="label__09f24__y83zE css-13r89hs ewsdu8x6" for="search_description"><span alt="Find" aria-hidden="false" aria-label="Find" class="icon--18-search-small css-17ed4v1" role="img"><svg class="icon_svg" height="18" width="18"><path d="M15.913 14.224a1.324 1.324 0 0 0-.3-.466h.009l-3.377-3.376a5.492 5.492 0 0 0 .802-2.857 5.523 5.523 0 1 0-5.522 5.52 5.491 5.491 0 0 0 2.856-.801l3.369 3.369.004.003c.132.131.293.231.471.298.143.053.296.086.458.086.727 0 1.317-.589 1.317-1.316 0-.163-.033-.317-.087-.46zM7.525 10.94a3.422 3.422 0 0 1-3.418-3.416 3.422 3.422 0 0 1 3.418-3.417 3.422 3.422 0 0 1 3.416 3.417 3.421 3.421 0 0 1-3.416 3.416z"></path></svg></span></label><div aria-expanded="false" aria-haspopup="listbox" class="ewsdu8x3 e140vcx52 css-7xcklk" role="combobox"><input aria-hidden="true" autocomplete="off" class="input__09f24__yaqh1 css-1y1s7b9 e140vcx50" data-testid="hiddenInput" disabled="" placeholder=" " spellcheck="false" tabindex="-1" type="text" value=""/><input aria-autocomplete="list" autocomplete="off" class="input__09f24__yaqh1 css-p8xp6y e140vcx51" data-testid="realInput" id="search_description" name="find_desc" placeholder="things to do, nail salons, plumbers" tabindex="0" type="search" value=""/></div></div><div class="ewsdu8x0 css-jmku3q"><label class="label__09f24__y83zE css-13r89hs ewsdu8x6" for="search_location"><span alt="Near" aria-hidden="false" aria-label="Near" class="icon--16-marker-v2 css-1mt9i4y" role="img"><svg class="icon_svg" height="16" wid ...
# <script data-hypernova-id="bdd1322d-8d7a-48dd-b5ab-07c8bf2f197a" data-hypernova-key="yelpfrontend__15489__yelpfrontend__GondolaBizDetails__dynamic" type="application/json"><!--{"locale":"en_US","messages":{},"requestCookies":{},"requestHeaders":{"user-agent":"python-requests/2.31.0","referer":null},"requestPath":"/biz/mejico-sydney-2","requestUrl":"https://www.yelp.com/biz/mejico-sydney-2","requestTimestampMs":1713336379407,"routeParams":{"businessEncidOrAlias":"mejico-sydney-2"},"userId":null,"bizUserId":null,"uniqueRequestId":"e02e8733c0de9c4c","site":"www","gaConfig":{"clientID":"69FEC5E8F1B1D5BC","dimensions":{"global":{"full_url":[15,"/biz/mejico-sydney-2"],"internal_ip":[18,false],"referrer":[28,"none"]},"www":{"full_url":[34,"/biz/mejico-sydney-2"],"internal_ip":[27,false],"referrer":[64,"none"]}},"domain":"yelp.com","enable_high_volume_events":false,"ga_enabled":true,"js_dimensions":{"global":{},"www":{}},"metrics":{"global":{},"www":{}},"trackers":{"www":"UA-30501-24","global":"UA-30501-1"},"user_id":null,"customParameters":{"guv":"69FEC5E8F1B1D5BC","known_bot":"other","remote_ip":"34.32.221.0","full_url":"/biz/mejico-sydney-2","internal_ip":false,"referrer":"none"}},"guv":"69FEC5E8F1B1D5BC","legacyProps":{"bizDetailsProps":{"bizDetailsMetaProps":{"businessId":"n6POlWRs0X9c6caknED8hA","staticUrl":"https://www.yelp.com/biz/mejico-sydney-2","selectedReviewId":null,"interfaceLanguageCode":"en","cityPageAlias":"sydney","appLinks":{"androidUrl":null,"iosUrl":"https://www.yelp.com/biz/mejico-sydney-2?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=apple"},"disallowedRobotsDirectives":null,"googleAppTags":{"androidUrl":"android-app://com.yelp.android/yelp-app-indexing/biz/n6POlWRs0X9c6caknED8hA?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google","iosUrl":"ios-app://284910350/yelp//biz/n6POlWRs0X9c6caknED8hA?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google"},"msiteUrl":"https://m.yelp.com/biz/mejico-sydney-2"},"bizDetailsPageProps":{"adUnitsAboveReviewProps":null,"adUnitsBelowReviewProps":null,"adUnitsSidebarProps":null,"autoOpeningMessagingModalProps":{"iframeUrls":{"mtb_search_ad":"/mtb_composer/business/n6POlWRs0X9c6caknED8hA/entry_point/mtb_search_ad?source_request_id=594d275489238d5b","mtb_landing_page":"/mtb_composer/business/n6POlWRs0X9c6caknED8hA/entry_point/mtb_landing_page?source_request_id=594d275489238d5b","third_party_deep_link":"/mtb_composer/business/n6POlWRs0X9c6caknED8hA/entry_point/third_party_deep_link?source_request_id=594d275489238d5b","mtb_search_action":"/mtb_composer/business/n6POlWRs0X9c6caknED8hA/entry_point/mtb_search_action?source_request_id=594d275489238d5b"}},"bizDiscoveryTopPitchProps":null,"bizPortfolioProps":null,"bizQuestionsProps":null,"businessAlertProps":null,"businessId":"n6POlWRs0X9c6caknED8hA","businessIsAdvertiser":false,"businessName":"Mejico","businessPostsCarouselProps":{"businessAvatar":{"bizPhoto":null,"id":"kEVvHLtBlb2dsQ60waOXiw","urlPrefix":"https://s3-media0.fl.yelpcdn.com/bphoto/kEVvHLtBlb2dsQ60waOXiw/","urlSuffix":".jpg"},"businessId":"n6POlWRs0X9c6caknED8hA","businessName":"Mejico","flagPostCsrftok":"5e232722d502c77b7935d16f1d097773aadc5806411b980edca64aa386e36226","insertPostInteractionCsrftok":"dfabc70ffd363b7b58a4a76a4002a6f805d6a03d5e736e47612aa34f2adb4c8d","deletePostInteractionCsrftok":"e022396077af12fffabf77480ab2ea6e524dbe101c202baa0d5cce5bcae146e8","posts":[],"currentUserId":null,"isQueryPostActive":false,"queryPostId":null,"querySource":null,"showLikeFeature":true},"callToActionProps":null,"conversationWidgetProps":null,"checkInOfferProps":null,"cityPageAlias":"sydney","collectionCardCarouselProps":{"collections":[{"url":"/collection/O_NavIaQ0DVqVac3vhgx-A","itemCount":61,"name":"Best Restaurants Sydney","owner":{"displayName":"Lukas T."},"photos":[{"sourceUrl":"https://s3-media0.fl.yelpcdn.com/bphoto/woHexTh0vr-hhBFtxzNOhA/300s.jpg"}]},{"url":"/collection/Dr-jIZ-WxfoI1XddahNRdA","itemCount":60,"name":"Sydney! ...
# <script crossorigin="anonymous" integrity="sha384-bm7MnzvK++ykSwVJ2tynSE5TRdN+xL418osEVF2DE/L/gfWHj91J2Sphe582B1Bh" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/64141792105e/assets/vendor/react-dom/18.2.0/umd/react-dom.production.min.js"></script>
# <!-- css-middleware: body tag placeholder --><script>(function() { var e=window.yelp.critical_css;function t(e){setTimeout(e,0)}function n(n){for(var o in e.css_map)if(!e.css_map[o].loaded)return;t(n)}function o(t,o){var a=e.css_map[t],i=a.linkTag,r=document.querySelector('style[data-critical-css="'+t+'"]');if(r&&i&&!a.loaded){var c=function(e,t){var n=e.cloneNode();n.rel="stylesheet",n.media="all",n.href=e.href;var o=function(){this.onload=null,this.setAttribute("onload",null),t.parentNode.removeChild(t)};return n.setAttribute("onload",o),n.onload=o,n}(i,r);r.insertAdjacentElement("afterend",c),i.parentNode.removeChild(i),e.css_map[t].loaded=!0,n(o)}else n(o)}function a(n,a){if(!e.css_map||0===Object.keys(e.css_map).length)return void t(n);(a?[a]:Object.keys(e.css_map)).forEach((function(t){e.lowPriorityMode?o(t,n):setTimeout(o,0,t,n)}))}e.criticalCSSReady=function(t){const n=(o=t,function(){return o&&(r=o.apply(i||this,arguments),o=null),r});var o,i,r;a(n);var c=e.recordDone.bind(window);e.recordDone=function(e,t){c.call(this,e,t),a(n,t.dataset.criticalCss)}}; })()</script>
# <script data-id="react-root-props">
#                 window.yelp = window.yelp || {};
#                 window.yelp.react_root_props = {"locale": "en_US", "messages": {}, "requestCookies": {}, "requestHeaders": {"user-agent": "python-requests/2.31.0", "referer": null}, "requestPath": "/biz/mejico-sydney-2", "requestUrl": "https://www.yelp.com/biz/mejico-sydney-2", "requestTimestampMs": 1713336379407, "routeParams": {"businessEncidOrAlias": "mejico-sydney-2"}, "userId": null, "bizUserId": null, "uniqueRequestId": "e02e8733c0de9c4c", "site": "www", "gaConfig": {"clientID": "69FEC5E8F1B1D5BC", "dimensions": {"global": {"full_url": [15, "/biz/mejico-sydney-2"], "internal_ip": [18, false], "referrer": [28, "none"]}, "www": {"full_url": [34, "/biz/mejico-sydney-2"], "internal_ip": [27, false], "referrer": [64, "none"]}}, "domain": "yelp.com", "enable_high_volume_events": false, "ga_enabled": true, "js_dimensions": {"global": {}, "www": {}}, "metrics": {"global": {}, "www": {}}, "trackers": {"www": "UA-30501-24", "global": "UA-30501-1"}, "user_id": null, "customParameters": {"guv": "69FEC5E8F1B1D5BC", "known_bot": "other", "remote_ip": "34.32.221.0", "full_url": "/biz/mejico-sydney-2", "internal_ip": false, "referrer": "none"}}, "guv": "69FEC5E8F1B1D5BC", "legacyProps": {"bizDetailsProps": {"bizDetailsMetaProps": {"businessId": "n6POlWRs0X9c6caknED8hA", "staticUrl": "https://www.yelp.com/biz/mejico-sydney-2", "selectedReviewId": null, "interfaceLanguageCode": "en", "cityPageAlias": "sydney", "appLinks": {"androidUrl": null, "iosUrl": "https://www.yelp.com/biz/mejico-sydney-2?utm_campaign=biz_details&utm_medium=organic&utm_source=apple"}, "disallowedRobotsDirectives": null, "googleAppTags": {"androidUrl": "android-app://com.yelp.android/yelp-app-indexing/biz/n6POlWRs0X9c6caknED8hA?utm_campaign=biz_details&utm_medium=organic&utm_source=google", "iosUrl": "ios-app://284910350/yelp//biz/n6POlWRs0X9c6caknED8hA?utm_campaign=biz_details&utm_medium=organic&utm_source=google"}, "msiteUrl": "https://m.yelp.com/biz/mejico-sydney-2"}, "bizDetailsPageProps": {"adUnitsAboveReviewProps": null, "adUnitsBelowReviewProps": null, "adUnitsSidebarProps": null, "autoOpeningMessagingModalProps": {"iframeUrls": {"mtb_search_ad": "/mtb_composer/business/n6POlWRs0X9c6caknED8hA/entry_point/mtb_search_ad?source_request_id=594d275489238d5b", "mtb_landing_page": "/mtb_composer/business/n6POlWRs0X9c6caknED8hA/entry_point/mtb_landing_page?source_request_id=594d275489238d5b", "third_party_deep_link": "/mtb_composer/business/n6POlWRs0X9c6caknED8hA/entry_point/third_party_deep_link?source_request_id=594d275489238d5b", "mtb_search_action": "/mtb_composer/business/n6POlWRs0X9c6caknED8hA/entry_point/mtb_search_action?source_request_id=594d275489238d5b"}}, "bizDiscoveryTopPitchProps": null, "bizPortfolioProps": null, "bizQuestionsProps": null, "businessAlertProps": null, "businessId": "n6POlWRs0X9c6caknED8hA", "businessIsAdvertiser": false, "businessName": "Mejico", "businessPostsCarouselProps": {"businessAvatar": {"bizPhoto": null, "id": "kEVvHLtBlb2dsQ60waOXiw", "urlPrefix": "https://s3-media0.fl.yelpcdn.com/bphoto/kEVvHLtBlb2dsQ60waOXiw/", "urlSuffix": ".jpg"}, "businessId": "n6POlWRs0X9c6caknED8hA", "businessName": "Mejico", "flagPostCsrftok": "5e232722d502c77b7935d16f1d097773aadc5806411b980edca64aa386e36226", "insertPostInteractionCsrftok": "dfabc70ffd363b7b58a4a76a4002a6f805d6a03d5e736e47612aa34f2adb4c8d", "deletePostInteractionCsrftok": "e022396077af12fffabf77480ab2ea6e524dbe101c202baa0d5cce5bcae146e8", "posts": [], "currentUserId": null, "isQueryPostActive": false, "queryPostId": null, "querySource": null, "showLikeFeature": true}, "callToActionProps": null, "conversationWidgetProps": null, "checkInOfferProps": null, "cityPageAlias": "sydney", "collectionCardCarouselProps": {"collections": [{"url": "/collection/O_NavIaQ0DVqVac3vhgx-A", "itemCount": 61, "name": "Best Restaurants Sydney", "owner": {"displayName": "Lukas T."}, "photos": [{"sourceUrl": "https://s3-media0.fl.yelpcdn.com/bphoto/woHexTh0vr-hhBFtxzNOhA/300s.jpg"}]}, {"url": "/collection/Dr-j ...
#             </script>
# <script crossorigin="anonymous" integrity="sha384-VWXV8VA+0xZuNh5mksoTGTWM4qM9gdLvcv/y/f3Ps2ZjKN37taVfpJHexdLG2bJI" src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/4dc644e84e0b/assets/vendor/regenerator-runtime/0.13.9/regenerator-runtime.min.js"></script>
# <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "5f372a3853645bced6a71e10626ad2d31335d5bf", "metaData": {"projectName": "gondola-biz-details", "activeVersion": "1.54.89", "deploymentPreviewId": null, "zipkinTraceID": "0c52135767713ce0"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1}, "client": "bugsnag", "apiKey": "7a505cfcfc5a2e124a4f37054c4d684d", "enabled": true}</script>
# <script data-source="loadable-ssr" id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[94591,36824,35119,25147,94629,81561,68362,63117,54690,5188,42147,8370,82042,68471,26405,51705,46048,79099,91771,51196,68594,44151,51093,12910,78785,13089,86753,71755,27854,18141,86751]</script><script data-source="loadable-ssr" id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["ClaimStatusGQL","ClaimReminderGQL","components-UnconfirmedReviewAlert","components-BizPageConfigurableAlertsGQL","components-BusinessPostsGQL","OnTheMenuGQL","MapBoxV2GQL","BizHoursGQL","components-MoreBusinessInfo","components-BizQuestionsGQL","Reviews","components-CollectionCardCarousel","components-RelatedBusinessesCarousel","components-SEOLinks"]}</script>
# <script async="" data-chunk="ClaimStatusGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-964f91986fe1f701f654.chunk.js"></script>
# <script async="" data-chunk="ClaimReminderGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimReminderGQL.yji-25267290e33dcb9e2de7.chunk.js"></script>
# <script async="" data-chunk="components-UnconfirmedReviewAlert" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-UnconfirmedReviewAlert.yji-af01e4e9b3e148d54e5b.chunk.js"></script>
# <script async="" data-chunk="components-BizPageConfigurableAlertsGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-22646887c4fdc1acab49.chunk.js"></script>
# <script async="" data-chunk="components-BusinessPostsGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BusinessPostsGQL.yji-7c9b3e012d3a8b1366c0.chunk.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-c618614aca1458d5bde2c6e5c567d2e268b6d9b2.yji-1eeae3ac4ad4a880ec95.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-80cc6ba903bd8dc0db2ea47b066e464f4b0e3ad7.yji-27b2217c00e3e7ad4c41.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-4385ce806a9aa42b8b757d0e0141a02132ddf8e2.yji-b389a61294e63009388f.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_shared-a55b3590195b5b65959d6e783f1c7d019ef6538c.yji-2758c2b8dc232ec61a6e.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-97b496f4a6e24001c8f4.chunk.js"></script>
# <script async="" data-chunk="OnTheMenuGQL" data-source="loadable-ssr" src="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji
type="text/javascript">window.yelp.initReactComponents();</script></body></html>

# %%
results[0].text
# Out:
# 'The food is fresh and tasty.  The scallop ceviche started the lunch. The scallops were tender with a great acidity and use of mango and peppers. The steak was tender and I got the hint of tequila in the sauce. I enjoyed a watermelon salad that complimented the the steak. The portions are good, but a stretch if you are sharing. My only down point is the service. They really only showed up to present my next plate and never checked to see if I wanted another drink (which I did).Enjoyed the food.'

# %%
reviews[0]
# Out:
# 'The food is fresh and tasty.  The scallop ceviche started the lunch. The scallops were tender with a great acidity and use of mango and peppers. The steak was tender and I got the hint of tequila in the sauce. I enjoyed a watermelon salad that complimented the the steak. The portions are good, but a stretch if you are sharing. My only down point is the service. They really only showed up to present my next plate and never checked to see if I wanted another drink (which I did).Enjoyed the food.'

# %% [markdown]
# ## Load Reviews into DataFrame and Score

# %%
df = pd.DataFrame(np.array(reviews),columns=['review'])
df.head()
# Out:
#                                               review
# 0  The food is fresh and tasty.  The scallop cevi...
# 1  The food was decent not great..  We had the gu...
# 2  Food was okay, guacamole was below average. Se...
# 3  The food and service here was really good.  It...
# 4  Visiting from Texas and decided to give this r...

# %%
df.shape
# Out:
# (10, 1)

# %%
df['review'].iloc[0]
# Out:
# 'The food is fresh and tasty.  The scallop ceviche started the lunch. The scallops were tender with a great acidity and use of mango and peppers. The steak was tender and I got the hint of tequila in the sauce. I enjoyed a watermelon salad that complimented the the steak. The portions are good, but a stretch if you are sharing. My only down point is the service. They really only showed up to present my next plate and never checked to see if I wanted another drink (which I did).Enjoyed the food.'

# %%
def sentiment_score(review):
  tokens = tokenizer.encode(review, return_tensors='pt')
  result = model(tokens)
  return int(torch.argmax(result.logits)) + 1

# %%
sentiment_score(df['review'].iloc[1])
# Out:
# 2

# %%
df['sentiment'] = df['review'].apply(lambda x:sentiment_score(x[:512]))

# %%
df.head()
# Out:
#                                               review  sentiment
# 0  The food is fresh and tasty.  The scallop cevi...          4
# 1  The food was decent not great..  We had the gu...          2
# 2  Food was okay, guacamole was below average. Se...          2
# 3  The food and service here was really good.  It...          5
# 4  Visiting from Texas and decided to give this r...          5

# %%
df
# Out:
#                                               review  sentiment
# 0  The food is fresh and tasty.  The scallop cevi...          4
# 1  The food was decent not great..  We had the gu...          2
# 2  Food was okay, guacamole was below average. Se...          2
# 3  The food and service here was really good.  It...          5
# 4  Visiting from Texas and decided to give this r...          5
# 5  Don't come here expecting legit Mexican food b...          3
# 6  Out of all the restaurants that I tried in Syd...          5
# 7  Great atmosphere, attentive service, solid mar...          3
# 8  We came here on a Thursday night @ 5pm and by ...          4
# 9  Have been here twice and have absolutely loved...          5

# %%
df['review'].iloc[1]
# Out:
# 'The food was decent not great..  We had the guacamole which was bland and came with some type of plantain chips.. The chicken and steak tacos were good.. But the service was poor. We had a waitress with an attitude. She seemed upset whenever we asked for anything.  She would walk by and just stick up her hand and say " just wait ".  She spilled the ingredients to make the guacamole all over the table but never apologized. The waitress didn\'t come by at all, not even once to check on us.. I will not go back. Suggest you find a Mexican restaurant that really wants your business..'
