# %% [markdown]
# Install spacy

# %%
# !pip install spacy

# %% [markdown]
# install english language

# %%
# !python -m spacy download en_core_web_sm

# %% [markdown]
# import spacy for use

# %%
import spacy

# %% [markdown]
# load spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# spacy containter

# %%
text = '''The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or informally as America, is a country primarily located in North America consisting of 50 states, a federal district, five major unincorporated territories, nine Minor Outlying Islands,[i] and 326 Indian reservations. It is the world's third-largest country by both land and total area.[c] It shares land borders with Canada to its north and with Mexico to its south and has maritime borders with the Bahamas, Cuba, Russia, and other nations.[j] With a population of over 333 million,[k] it is the most populous country in the Americas and the third-most populous in the world. The national capital of the United States is Washington, D.C., and its most populous city and principal financial center is New York City.

Indigenous peoples have inhabited the Americas for thousands of years. Beginning in 1607, British colonization led to the establishment of the Thirteen Colonies in what is now the Eastern United States. They quarreled with the British Crown over taxation and political representation, leading to the American Revolution and ensuing Revolutionary War. The United States declared independence on July 4, 1776, becoming the first nation-state founded on Enlightenment principles of unalienable natural rights, consent of the governed, and liberal democracy. The country began expanding across North America, spanning the continent by 1848. Sectional division over slavery led to the secession of the Confederate States of America, which fought the remaining states of the Union during the American Civil War (1861–1865). With the Union's victory and preservation, slavery was abolished nationally.

By 1900, the United States had established itself as a great power, becoming the world's largest economy. After Japan's attack on Pearl Harbor in 1941, the U.S. entered World War II on the Allied side. The aftermath of the war left the United States and the Soviet Union as the world's two superpowers and led to the Cold War. During the Cold War, both countries engaged in a struggle for ideological dominance but avoided direct military conflict. They also competed in the Space Race, which culminated in the 1969 landing of Apollo 11, making the U.S. the first and only nation to land humans on the Moon. With the Soviet Union's collapse and the subsequent end of the Cold War in 1991, the United States emerged as the world's sole superpower.

The United States government is a federal republic and a representative democracy with three separate branches of government. It has a bicameral national legislature composed of the House of Representatives, a lower house; and the Senate, an upper house based on equal representation for each state. Many policy issues are decentralized at a state or local level, with widely differing laws by jurisdiction. The U.S. ranks highly in international measures of quality of life, income and wealth, economic competitiveness, human rights, innovation, and education; it has low levels of perceived corruption. It has higher levels of incarceration and inequality than most other developed nations, and is the only developed nation without universal healthcare. As a melting pot of cultures and ethnicities, the U.S. has been shaped by the world's largest immigrant population.

The United States is a highly developed country that has one of highest median income of any polity in the world. Its economy accounts for approximately a quarter of global GDP and is the world's largest by GDP at market exchange rates. It is the world's largest importer and second-largest exporter, and possesses the largest amount of wealth of any country. The United States is a founding member of the United Nations, World Bank, International Monetary Fund, Organization of American States, NATO, World Health Organization, and is a permanent member of the United Nations Security Council. It is the world's foremost political, cultural, economic, military, and scientific force.'''

# %%
text
# Out:
# "The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or informally as America, is a country primarily located in North America consisting of 50 states, a federal district, five major unincorporated territories, nine Minor Outlying Islands,[i] and 326 Indian reservations. It is the world's third-largest country by both land and total area.[c] It shares land borders with Canada to its north and with Mexico to its south and has maritime borders with the Bahamas, Cuba, Russia, and other nations.[j] With a population of over 333 million,[k] it is the most populous country in the Americas and the third-most populous in the world. The national capital of the United States is Washington, D.C., and its most populous city and principal financial center is New York City.\n\nIndigenous peoples have inhabited the Americas for thousands of years. Beginning in 1607, British colonization led to the establishment of the Thirteen Colonies in what is now the Eastern United States. They quarreled with the British Crown over taxation and political representation, leading to the American Revolution and ensuing Revolutionary War. The United States declared independence on July 4, 1776, becoming the first nation-state founded on Enlightenment principles of unalienable natural rights, consent of the governed, and liberal democracy. The country began expanding across North America, spanning the continent by 1848. Sectional division over slavery led to the secession of the Confederate States of America, which fought the remaining states of the Union during the American Civil War (1861–1865). With the Union's victory and preservation, slavery was abolished nationally.\n\nBy 1900, the United States had established itself as a great power, becoming the world's largest economy. After Japan's attack on Pearl Harbor in 1941, the U.S. entered World War II on the Allied side. The aftermath of the war left the United States and the Soviet Union as the world's two superpowers and led to the Cold War. During the Cold War, both countries engaged in a struggle for ideological dominance but avoided direct military conflict. They also competed in the Space Race, which culminated in the 1969 landing of Apollo 11, making the U.S. the first and only nation to land humans on the Moon. With the Soviet Union's collapse and the subsequent end of the Cold War in 1991, the United States emerged as the world's sole superpower.\n\nThe United States government is a federal republic and a representative democracy with three separate branches of government. It has a bicameral national legislature composed of the House of Representatives, a lower house; and the Senate, an upper house based on equal representation for each state. Many policy issues are decentralized at a state or local level, with widely differing laws by jurisdiction. The U.S. ranks highly in international measures of quality of life, income and wealth, economic competitiveness, human rights, innovation, and education; it has low levels of perceived corruption. It has higher levels of incarceration and inequality than most other developed nations, and is the only developed nation without universal healthcare. As a melting pot of cultures and ethnicities, the U.S. has been shaped by the world's largest immigrant population.\n\nThe United States is a highly developed country that has one of highest median income of any polity in the world. Its economy accounts for approximately a quarter of global GDP and is the world's largest by GDP at market exchange rates. It is the world's largest importer and second-largest exporter, and possesses the largest amount of wealth of any country. The United States is a founding member of the United Nations, World Bank, International Monetary Fund, Organization of American States, NATO, World Health Organization, and is a permanent member of the United Nations Security Council. It is the world's foremost political, cultural, economic, militar ...

# %% [markdown]
# The Doc Attributes

# %%
doc = nlp(text)

# %%
print(doc)
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or informally as America, is a country primarily located in North America consisting of 50 states, a federal district, five major unincorporated territories, nine Minor Outlying Islands,[i] and 326 Indian reservations. It is the world's third-largest country by both land and total area.[c] It shares land borders with Canada to its north and with Mexico to its south and has maritime borders with the Bahamas, Cuba, Russia, and other nations.[j] With a population of over 333 million,[k] it is the most populous country in the Americas and the third-most populous in the world. The national capital of the United States is Washington, D.C., and its most populous city and principal financial center is New York City.
#
# Indigenous peoples have inhabited the Americas for thousands of years. Beginning in 1607, British colonization led to the establishment of the Thirteen Colonies in what is now the Eastern United States. They quarreled with the British Crown over taxation and political representation, leading to the American Revolution and ensuing Revolutionary War. The United States declared independence on July 4, 1776, becoming the first nation-state founded on Enlightenment principles of unalienable natural rights, consent of the governed, and liberal democracy. The country began expanding across North America, spanning the continent by 1848. Sectional division over slavery led to the secession of the Confederate States of America, which fought the remaining states of the Union during the American Civil War (1861–1865). With the Union's victory and preservation, slavery was abolished nationally.
#
# By 1900, the United States had established itself as a great power, becoming the world's largest economy. After Japan's attack on Pearl Harbor in 1941, the U.S. entered World War II on the Allied side. The aftermath of the war left the United States and the Soviet Union as the world's two superpowers and led to the Cold War. During the Cold War, both countries engaged in a struggle for ideological dominance but avoided direct military conflict. They also competed in the Space Race, which culminated in the 1969 landing of Apollo 11, making the U.S. the first and only nation to land humans on the Moon. With the Soviet Union's collapse and the subsequent end of the Cold War in 1991, the United States emerged as the world's sole superpower.
#
# The United States government is a federal republic and a representative democracy with three separate branches of government. It has a bicameral national legislature composed of the House of Representatives, a lower house; and the Senate, an upper house based on equal representation for each state. Many policy issues are decentralized at a state or local level, with widely differing laws by jurisdiction. The U.S. ranks highly in international measures of quality of life, income and wealth, economic competitiveness, human rights, innovation, and education; it has low levels of perceived corruption. It has higher levels of incarceration and inequality than most other developed nations, and is the only developed nation without universal healthcare. As a melting pot of cultures and ethnicities, the U.S. has been shaped by the world's largest immigrant population.
#
# The United States is a highly developed country that has one of highest median income of any polity in the world. Its economy accounts for approximately a quarter of global GDP and is the world's largest by GDP at market exchange rates. It is the world's largest importer and second-largest exporter, and possesses the largest amount of wealth of any country. The United States is a founding member of the United Nations, World Bank, International Monetary Fund, Organization of American States, NATO, World Health Organization, and is a permanent member of the United Nations Security Council. It is the world's foremost political, cultural, economic, military, and scientific force.

# %%
print(len(text))
print(len(doc))
# Out:
# 4015
# 742

# %%
for token in text[0:10]:
  print(token)
# Out:
# T
# h
# e
#
# U
# n
# i
# t
# e
# d

# %%
for token in doc[0:10]:
  print(token)
# Out:
# The
# United
# States
# of
# America
# (
# U.S.A.
# or
# USA
# )

# %%
for token in text.split()[:10]:
  print(token)
# Out:
# The
# United
# States
# of
# America
# (U.S.A.
# or
# USA),
# commonly
# known

# %%
for sent in doc.sents:
  print(sent)
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or informally as America, is a country primarily located in North America consisting of 50 states, a federal district, five major unincorporated territories, nine Minor Outlying Islands,[i] and 326 Indian reservations.
# It is the world's third-largest country by both land and total area.[c] It shares land borders with Canada to its north and with Mexico to its south and has maritime borders with the Bahamas, Cuba, Russia, and other nations.[j]
# With a population of over 333 million,[k] it is the most populous country in the Americas and the third-most populous in the world.
# The national capital of the United States is Washington, D.C., and its most populous city and principal financial center is New York City.
#
#
# Indigenous peoples have inhabited the Americas for thousands of years.
# Beginning in 1607, British colonization led to the establishment of the Thirteen Colonies in what is now the Eastern United States.
# They quarreled with the British Crown over taxation and political representation, leading to the American Revolution and ensuing Revolutionary War.
# The United States declared independence on July 4, 1776, becoming the first nation-state founded on Enlightenment principles of unalienable natural rights, consent of the governed, and liberal democracy.
# The country began expanding across North America, spanning the continent by 1848.
# Sectional division over slavery led to the secession of the Confederate States of America, which fought the remaining states of the Union during the American Civil War (1861–1865).
# With the Union's victory and preservation, slavery was abolished nationally.
#
#
# By 1900, the United States had established itself as a great power, becoming the world's largest economy.
# After Japan's attack on Pearl Harbor in 1941, the U.S. entered World War II on the Allied side.
# The aftermath of the war left the United States and the Soviet Union as the world's two superpowers and led to the Cold War.
# During the Cold War, both countries engaged in a struggle for ideological dominance but avoided direct military conflict.
# They also competed in the Space Race, which culminated in the 1969 landing of Apollo 11, making the U.S. the first and only nation to land humans on the Moon.
# With the Soviet Union's collapse and the subsequent end of the Cold War in 1991, the United States emerged as the world's sole superpower.
#
#
# The United States government is a federal republic and a representative democracy with three separate branches of government.
# It has a bicameral national legislature composed of the House of Representatives, a lower house; and the Senate, an upper house based on equal representation for each state.
# Many policy issues are decentralized at a state or local level, with widely differing laws by jurisdiction.
# The U.S. ranks highly in international measures of quality of life, income and wealth, economic competitiveness, human rights, innovation, and education; it has low levels of perceived corruption.
# It has higher levels of incarceration and inequality than most other developed nations, and is the only developed nation without universal healthcare.
# As a melting pot of cultures and ethnicities, the U.S. has been shaped by the world's largest immigrant population.
#
#
# The United States is a highly developed country that has one of highest median income of any polity in the world.
# Its economy accounts for approximately a quarter of global GDP and is the world's largest by GDP at market exchange rates.
# It is the world's largest importer and second-largest exporter, and possesses the largest amount of wealth of any country.
# The United States is a founding member of the United Nations, World Bank, International Monetary Fund, Organization of American States, NATO, World Health Organization, and is a permanent member of the United Nations Security Council.
# It is the world's foremost political, cultural, economic, military, and scientific force.

# %%
sent1  = list(doc.sents)[0]
print(sent1)
# Out:
# The United States of America (U.S.A. or USA), commonly known as the United States (U.S. or US) or informally as America, is a country primarily located in North America consisting of 50 states, a federal district, five major unincorporated territories, nine Minor Outlying Islands,[i] and 326 Indian reservations.

# %% [markdown]
# The token attributes

# %%
for token in doc[:10]:
  print(token)
# Out:
# The
# United
# States
# of
# America
# (
# U.S.A.
# or
# USA
# )

# %%
token2 = sent1[2]
print(token2)
# Out:
# States

# %%
token2.text
# Out:
# 'States'

# %%
token2.left_edge
# Out:
# The

# %%
token2.right_edge
# Out:
# America

# %%
token2.ent_type_
# Out:
# 'GPE'

# %%
token2.ent_iob_
# Out:
# 'I'

# %%
token2.lemma_
# Out:
# 'States'

# %%
sent1[12].lemma_
# Out:
# 'know'

# %%
sent1[12]
# Out:
# known

# %%
token2.morph
# Out:
# Number=Sing

# %%
sent1[12].morph
# Out:
# Aspect=Perf|Tense=Past|VerbForm=Part

# %%
token2.pos_
# Out:
# 'PROPN'

# %%
token2.dep_
# Out:
# 'nsubj'

# %%
token2.lang_
# Out:
# 'en'

# %% [markdown]
# part of speech

# %%
text = 'mike enjoys playing football'
doc2 = nlp(text)
print(doc2)
# Out:
# mike enjoys playing football

# %%
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# mike PROPN nsubj
# enjoys VERB ROOT
# playing VERB xcomp
# football NOUN dobj

# %%
from spacy import displacy

displacy.render(doc2,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4e466716c8b6483e91290a3af57f194d-0" class="displacy" width="750" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">mike</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">enjoys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">playing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">football</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e466716c8b6483e91290a3af57f194d-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e466716c8b6483e91290a3af57f194d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e466716c8b6483e91290a3af57f194d-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e466716c8b6483e91290a3af57f194d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,91.5 L408.0,79.5 392.0,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e466716c8b6483e91290a3af57f194d-0-2" stroke-width="2px" d="M420,89.5 C420,2.0 575.0,2.0 575.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e466716c8b6483e91290a3af57f194d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,91.5 L583.0,79.5 567.0,79.5" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# name entity reconition

# %%
for ent in doc.ents:
  print(ent.text,ent.label_)
# Out:
# The United States of America GPE
# U.S.A. GPE
# USA GPE
# the United States GPE
# U.S. GPE
# US GPE
# America GPE
# North America LOC
# 50 CARDINAL
# five CARDINAL
# nine CARDINAL
# Minor Outlying Islands,[i ORG
# 326 CARDINAL
# Indian NORP
# third ORDINAL
# Canada GPE
# Mexico GPE
# Bahamas GPE
# Cuba GPE
# Russia GPE
# 333 CARDINAL
# Americas LOC
# third ORDINAL
# the United States GPE
# Washington GPE
# D.C. GPE
# New York City GPE
# Americas LOC
# thousands of years DATE
# 1607 DATE
# British NORP
# the Thirteen Colonies ORG
# the Eastern United States GPE
# British NORP
# Crown PRODUCT
# the American Revolution EVENT
# Revolutionary War EVENT
# The United States GPE
# July 4, 1776 DATE
# first ORDINAL
# North America LOC
# 1848 DATE
# the Confederate States of America GPE
# the American Civil War EVENT
# 1861–1865 CARDINAL
# Union ORG
# 1900 DATE
# the United States GPE
# Japan GPE
# Pearl Harbor FAC
# 1941 DATE
# U.S. GPE
# World War II EVENT
# Allied ORG
# the United States GPE
# the Soviet Union GPE
# two CARDINAL
# the Cold War EVENT
# the Cold War EVENT
# the Space Race FAC
# 1969 DATE
# Apollo 11 LAW
# U.S. GPE
# first ORDINAL
# the Soviet Union's GPE
# the Cold War EVENT
# 1991 DATE
# the United States GPE
# United States GPE
# three CARDINAL
# the House of Representatives ORG
# Senate ORG
# U.S. GPE
# U.S. GPE
# The United States GPE
# one CARDINAL
# approximately a quarter DATE
# second ORDINAL
# The United States GPE
# the United Nations ORG
# World Bank ORG
# International Monetary Fund ORG
# Organization of American States ORG
# NATO ORG
# World Health Organization ORG
# the United Nations Security Council ORG

# %%
displacy.render(doc,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The United States of America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.A.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ), commonly known as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ) or informally as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , is a country primarily located in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  consisting of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  states, a federal district,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  major unincorporated territories,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minor Outlying Islands,[i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ] and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     326
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  reservations. It is the world's
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -largest country by both land and total area.[c] It shares land borders with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to its north and with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mexico
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to its south and has maritime borders with the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bahamas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cuba
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and other nations.[j] With a population of over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     333
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  million,[k] it is the most populous country in the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  and the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -most populous in the world. The national capital of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-hei
